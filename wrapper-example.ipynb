# %%
import mercadolibre as ml

# %% [markdown]
# ## Search by query and category

# %%
df = ml.get_df_from_query(query='bateria', category='MLB61076', items_per_query=100, total_results_limit=1000)
df.head()
# Out:
# Searching for "bateria" in iPhone sold by N/A...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1000
# 100%|██████████| 1000/1000 [00:13<00:00, 76.36it/s]
# Initial request sent to API: https://api.mercadolibre.com/sites/MLB/search?offset=0&q=bateria&category=MLB61076&limit=1
# 7624 results found.
#                                                           title  price  \
# id
# MLB679795497  Bateria Iphone 4s 4gs Original + Tampa Preta +...  84.99
# MLB680108022  Bateria Iphone 5s Original Apple A Pronta Entrega  34.98
# MLB680114615                       Bateria Iphone 4 4g Original  32.89
# MLB680280421        Bateria Iphone 5 / 5g Para Iphone Original.  45.99
# MLB680283060  Bateria Original Iphone 5 5g 5s 5c - Apple Pro...  19.90
#
#               sold_quantity  available_quantity  \
# id
# MLB679795497            218                 152
# MLB680108022             56                   3
# MLB680114615             29                 486
# ...

# %% [markdown]
# ## Search by seller

# %%
df = ml.get_df_from_query(seller_id='74620867', items_per_query=100, total_results_limit=1000)
df.head()
# Out:
# Searching for "N/A" in N/A sold by 74620867...
#   0%|          | 0/731 [00:00<?, ?it/s]
# 731
# 100%|██████████| 731/731 [00:06<00:00, 71.80it/s]
# Initial request sent to API: https://api.mercadolibre.com/sites/MLB/search?offset=0&q=&limit=1&category=&seller_id=74620867
# 731 results found.
#                                                           title   price  \
# id
# MLB679960578  Gravador De Áudio Tascam Dr-05 Portátil Digita...  452.98
# MLB680244975  Gravador Digital Zoom H1 Super Portátil Áudio ...  668.80
# MLB680263312  Headphone Sony Mdr-7506 Fone Profissional  Gra...  518.80
# MLB680279824                  Bateria Do Iphone 4 E 4s Original   41.99
# MLB680280421        Bateria Iphone 5 / 5g Para Iphone Original.   45.99
#
#               sold_quantity  available_quantity  \
# id
# MLB679960578              7                  43
# MLB680244975              5                  20
# MLB680263312            105                 149
# ...

# %%
df.permalink[0]
# Out:
# 'http://produto.mercadolivre.com.br/MLB-679960578-gravador-de-audio-tascam-dr-05-portatil-digital-wav-e-mp3-_JM'
